# %% [markdown]
# ## DATA VISUALIZATION AND DATA ANALYSIS

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Dataset.csv')
df.head()
# Out:
#    UDI Product ID Type  Air_temperature   Process_temperature   \
# 0    1     M14860    M             298.1                 308.6
# 1    2     L47181    L             298.2                 308.7
# 2    3     L47182    L             298.1                 308.5
# 3    4     L47183    L             298.2                 308.6
# 4    5     L47184    L             298.2                 308.7
#
#    Rotational_speed   Torque   Tool_wear   Target Failure_Type
# 0               1551     42.8           0       0   No Failure
# 1               1408     46.3           3       0   No Failure
# 2               1498     49.4           5       0   No Failure
# 3               1433     39.5           7       0   No Failure
# 4               1408     40.0           9       0   No Failure

# %%
df.columns
# Out:
# Index(['UDI', 'Product ID', 'Type', 'Air_temperature ', 'Process_temperature ',
#        'Rotational_speed ', 'Torque ', 'Tool_wear ', 'Target', 'Failure_Type'],
#       dtype='object')

# %%
del df['UDI']
del df['Product ID']
del df['Type']
del df['Target']

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

var = ['Failure_Type']
  
for i in var:
    df[i] = le.fit_transform(df[i]).astype(int)

# %%
plt.figure(figsize=(12,7))
sns.countplot(x='Failure_Type',data=df)
# Out:
# <Axes: xlabel='Failure_Type', ylabel='count'>

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
plt.hist(df['Failure_Type'],color='red')
# Out:
# (array([ 112.,    0., 9652.,    0.,   78.,    0.,   95.,    0.,   18.,
#           45.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
df.hist(figsize=(15,55),layout=(15,4), color='orange')
plt.show()

# %%
plt.scatter(df['Torque '],df["Tool_wear "]) # scatter, plot, triplot, stackplot

# %%
df['Torque '].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
sns.barplot(df['Failure_Type'], color='purple') 
# barplot, boxenplot, boxplot, countplot, displot, distplot, ecdfplot, histplot, kdeplot, pointplot, violinplot, stripplot
# Out:
# <Axes: ylabel='Failure_Type'>

# %%
fig, ax = plt.subplots(figsize=(20,15))
sns.heatmap(df.corr(),annot = True, fmt='0.2%',cmap = 'autumn',ax=ax)
# Out:
# <Axes: >

# %%
def plot(df, variable):
    dataframe_pie = df[variable].value_counts()
    ax = dataframe_pie.plot.pie(figsize=(9,9), autopct='%1.2f%%', fontsize = 10)
    ax.set_title(variable + ' \n', fontsize = 10)
    return np.round(dataframe_pie/df.shape[0]*100,2)

plot(df, 'Failure_Type')
# Out:
# Failure_Type
# 1    96.52
# 0     1.12
# 3     0.95
# 2     0.78
# 5     0.45
# 4     0.18
# Name: count, dtype: float64
